# %%
# Load the Tidyverse

library('tidyverse')
# Out:
# ── Attaching packages ─────────────────────────────────────── tidyverse 1.3.1 ──
#
# ✔ ggplot2 3.3.5     ✔ purrr   0.3.4
# ✔ tibble  3.1.4     ✔ dplyr   1.0.7
# ✔ tidyr   1.1.3     ✔ stringr 1.4.0
# ✔ readr   2.0.2     ✔ forcats 0.5.1
#
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()

# %% [markdown]
# Use the `pull` function to extract the `class` column from the `mpg` data set. Capture this column into a variable named `class_col`.

# %%
class_col = mpg %>% pull(name = "class")
# Out:
#      compact      compact      compact      compact      compact      compact
#    "compact"    "compact"    "compact"    "compact"    "compact"    "compact"
#      compact      compact      compact      compact      compact      compact
#    "compact"    "compact"    "compact"    "compact"    "compact"    "compact"
#      compact      compact      compact      midsize      midsize      midsize
#    "compact"    "compact"    "compact"    "midsize"    "midsize"    "midsize"
#          suv          suv          suv          suv          suv      2seater
#        "suv"        "suv"        "suv"        "suv"        "suv"    "2seater"
#      2seater      2seater      2seater      2seater          suv          suv
#    "2seater"    "2seater"    "2seater"    "2seater"        "suv"        "suv"
#          suv          suv      midsize      midsize      midsize      midsize
#        "suv"        "suv"    "midsize"    "midsize"    "midsize"    "midsize"
#      midsize      minivan      minivan      minivan      minivan      minivan
#    "midsize"    "minivan"    "minivan"    "minivan"    "minivan"    "minivan"
#      minivan      minivan      minivan      minivan      minivan      minivan
#    "minivan"    "minivan"    "minivan"    "minivan"    "minivan"    "minivan"
#       pickup       pickup       pickup       pickup       pickup       pickup
#     "pickup"     "pickup"     "pickup"     "pickup"     "pickup"     "pickup"
#       pickup       pickup       pickup          suv          suv          suv
#     "pickup"     "pickup"     "pickup"        "suv"        "suv"        "suv"
#          suv          suv          suv          suv       pickup       pickup
#        "suv"        "suv"        "suv"        "suv"     "pickup"     "pickup"
#       pickup       pickup       pickup       pickup       pickup       pickup
#     "pickup"     "pickup"     "pickup"     "pickup"     "pickup"     "pickup"
#       pickup       pickup          suv          suv          suv          suv
#     "pickup"     "pickup"        "suv"        "suv"        "suv"        "suv"
#          suv          suv          suv          suv          suv       pickup
#        "suv"        "suv"        "suv"        "suv"        "suv"     "pickup"
#       pickup       pickup       pickup       pickup       pickup       pickup
#     "pickup"     "pickup"     "pickup"     "pickup"     "pickup"     "pickup"
#   subcompact   subcompact   subcompact   subcompact   subcompact   subcompact
# "subcompact" "subcompact" "subcompact" "subcompact" "subcompact" "subcompact"
#   subcompact   subcompact   subcompact   subcompact   subcompact   subcompact
# "subcompact" "subcompact" "subcompact" "subcompact" "subcompact" "subcompact"
#   subcompact   subcompact   subcompact   subcompact   subcompact   subcompact
# "subcompact" "subcompact" "subcompact" "subcompact" "subcompact" "subcompact"
#      midsize      midsize      midsize      midsize      midsize      midsize
#    "midsize"    "midsize"    "midsize"    "midsize"    "midsize"    "midsize"
#      midsize   subcompact   subcompact   subcompact   subcompact   subcompact
#    "midsize" "subcompact" "subcompact" "subcompact" "subcompact" "subcompact"
#   subcompact   subcompact          suv          suv          suv          suv
# "subcompact" "subcompact"        "suv"        "suv"        "suv"        "suv"
#          suv          suv          suv          suv          suv          suv
#        "suv"        "suv"        "suv"        "suv"        "suv"        "suv"
#          suv          suv          suv          suv          suv          suv
#        "suv"        "suv"        "suv"        "suv"        "suv"        "suv"
#          suv          suv          suv      compact      compact      midsize
#        "suv"        "suv"        "suv"    "compact"    "compact"    "midsize"
#      midsize      midsize      midsize      midsize      midsize      midsize
#    "midsize"    "midsize"    "midsize"    "midsize"    "midsize"    "midsize"
#          suv          suv          suv          suv      midsize      midsize
#        "suv"        "suv"        "suv"        "suv"    "midsize"    "midsize"
#      midsize      midsize      midsize          suv          suv          suv
#    "midsize"    "midsize"    "midsize"        "suv"        "suv"        "suv"
#          suv          suv          suv   subcompact   subcompact   subcompact
#        "suv"        "suv"        "suv" "subcompact" "subcompact" "subcompact"
#   subcompact      compact      compact      compact      compact          suv
# "subcompact"    "compact"    "compact"    "compact"    "compact"        "suv"
#          suv          suv          suv          suv          suv      midsize
#        "suv"        "suv"        "suv"        "suv"        "suv"    "midsize"
#      midsize      midsize      midsize      midsize      midsize      midsize
#    "midsize"    "midsize"    "midsize"    "midsize"    "midsize"    "midsize"
#      compact      compact      compact      compact      compact      compact
#    "compact"    "compact"    "compact"    "compact"    "compact"    "compact"
#      compact      compact      compact      compact      compact      compact
#    "compact"    "compact"    "compact"    "compact"    "compact"    "compact"
#          suv          suv       pickup       pickup       pickup       pickup
#        "suv"        "suv"     "pickup"     "pickup"     "pickup"     "pickup"
#       pickup       pickup       pickup      compact      compact      compact
#     "pickup"     "pickup"     "pickup"    "compact"    "compact"    "compact"
#      compact      compact      compact      compact      compact      compact
#    "compact"    "compact"    "compact"    "compact"    "compact"    "compact"
#      compact      compact      compact      compact      compact   subcompact
#    "compact"    "compact"    "compact"    "compact"    "compact" "subcompact"
#   subcompact   subcompact   subcompact   subcompact   subcompact      midsize
# "subcompact" "subcompact" "subcompact" "subcompact" "subcompact"    "midsize"
#      midsize      midsize      midsize      midsize      midsize      midsize
#    "midsize"    "midsize"    "midsize"    "midsize"    "midsize"    "midsize"

# %% [markdown]
# Run the code below to turn `class_col` into a factor and view the default levels.

# %%
class_col %>% factor %>% levels
# Out:
# [1] "2seater"    "compact"    "midsize"    "minivan"    "pickup"
# [6] "subcompact" "suv"

# %% [markdown]
# Let's turn `class_col` into a factor but manipulate the order of the levels with `forcats`!

# %% [markdown]
# First, use the `table` command to count the frequency of each value in `class_col`.

# %%
class_col %>% table
# Out:
# .
#    2seater    compact    midsize    minivan     pickup subcompact        suv
#          5         47         41         11         33         35         62

# %% [markdown]
# Pipe `class_col` into the `fct_infreq` function to turn `class_col` into a factor and order the levels by ☝️frequency. Are the levels in the order you expected?

# %%
class_col %>% fct_infreq
# Out:
#    compact    compact    compact    compact    compact    compact    compact
#    compact    compact    compact    compact    compact    compact    compact
#    compact    compact    compact    compact    compact    compact    compact
#    compact    compact    compact    compact    compact    compact    compact
#    compact    midsize    midsize    midsize        suv        suv        suv
#    compact    midsize    midsize    midsize        suv        suv        suv
#        suv        suv    2seater    2seater    2seater    2seater    2seater
#        suv        suv    2seater    2seater    2seater    2seater    2seater
#        suv        suv        suv        suv    midsize    midsize    midsize
#        suv        suv        suv        suv    midsize    midsize    midsize
#    midsize    midsize    minivan    minivan    minivan    minivan    minivan
#    midsize    midsize    minivan    minivan    minivan    minivan    minivan
#    minivan    minivan    minivan    minivan    minivan    minivan     pickup
#    minivan    minivan    minivan    minivan    minivan    minivan     pickup
#     pickup     pickup     pickup     pickup     pickup     pickup     pickup
#     pickup     pickup     pickup     pickup     pickup     pickup     pickup
#     pickup        suv        suv        suv        suv        suv        suv
#     pickup        suv        suv        suv        suv        suv        suv
#        suv     pickup     pickup     pickup     pickup     pickup     pickup
#        suv     pickup     pickup     pickup     pickup     pickup     pickup
#     pickup     pickup     pickup     pickup        suv        suv        suv
#     pickup     pickup     pickup     pickup        suv        suv        suv
#        suv        suv        suv        suv        suv        suv     pickup
#        suv        suv        suv        suv        suv        suv     pickup
#     pickup     pickup     pickup     pickup     pickup     pickup subcompact
#     pickup     pickup     pickup     pickup     pickup     pickup subcompact
# subcompact subcompact subcompact subcompact subcompact subcompact subcompact
# subcompact subcompact subcompact subcompact subcompact subcompact subcompact
# subcompact subcompact subcompact subcompact subcompact subcompact subcompact
# subcompact subcompact subcompact subcompact subcompact subcompact subcompact
# subcompact subcompact subcompact    midsize    midsize    midsize    midsize
# subcompact subcompact subcompact    midsize    midsize    midsize    midsize
#    midsize    midsize    midsize subcompact subcompact subcompact subcompact
#    midsize    midsize    midsize subcompact subcompact subcompact subcompact
# subcompact subcompact subcompact        suv        suv        suv        suv
# subcompact subcompact subcompact        suv        suv        suv        suv
#        suv        suv        suv        suv        suv        suv        suv
#        suv        suv        suv        suv        suv        suv        suv
#        suv        suv        suv        suv        suv        suv        suv
#        suv        suv        suv        suv        suv        suv        suv
#        suv    compact    compact    midsize    midsize    midsize    midsize
#        suv    compact    compact    midsize    midsize    midsize    midsize
#    midsize    midsize    midsize        suv        suv        suv        suv
#    midsize    midsize    midsize        suv        suv        suv        suv
#    midsize    midsize    midsize    midsize    midsize        suv        suv
#    midsize    midsize    midsize    midsize    midsize        suv        suv
#        suv        suv        suv        suv subcompact subcompact subcompact
#        suv        suv        suv        suv subcompact subcompact subcompact
# subcompact    compact    compact    compact    compact        suv        suv
# subcompact    compact    compact    compact    compact        suv        suv
#        suv        suv        suv        suv    midsize    midsize    midsize
#        suv        suv        suv        suv    midsize    midsize    midsize
#    midsize    midsize    midsize    midsize    compact    compact    compact
#    midsize    midsize    midsize    midsize    compact    compact    compact
#    compact    compact    compact    compact    compact    compact    compact
#    compact    compact    compact    compact    compact    compact    compact
#    compact    compact        suv        suv     pickup     pickup     pickup
#    compact    compact        suv        suv     pickup     pickup     pickup
#     pickup     pickup     pickup     pickup    compact    compact    compact
#     pickup     pickup     pickup     pickup    compact    compact    compact
#    compact    compact    compact    compact    compact    compact    compact
#    compact    compact    compact    compact    compact    compact    compact
#    compact    compact    compact    compact subcompact subcompact subcompact
#    compact    compact    compact    compact subcompact subcompact subcompact
# subcompact subcompact subcompact    midsize    midsize    midsize    midsize
# subcompact subcompact subcompact    midsize    midsize    midsize    midsize
#    midsize    midsize    midsize
#    midsize    midsize    midsize
# Levels: suv compact midsize subcompact pickup minivan 2seater

# %% [markdown]
# Group the low frequency levels into an "Other" category using `fct_lump`. Set the `n` argument to **five**.

# %%
class_col %>% fct_lump(n=5)
# Out:
#    compact    compact    compact    compact    compact    compact    compact
#    compact    compact    compact    compact    compact    compact    compact
#    compact    compact    compact    compact    compact    compact    compact
#    compact    compact    compact    compact    compact    compact    compact
#    compact    midsize    midsize    midsize        suv        suv        suv
#    compact    midsize    midsize    midsize        suv        suv        suv
#        suv        suv    2seater    2seater    2seater    2seater    2seater
#        suv        suv      Other      Other      Other      Other      Other
#        suv        suv        suv        suv    midsize    midsize    midsize
#        suv        suv        suv        suv    midsize    midsize    midsize
#    midsize    midsize    minivan    minivan    minivan    minivan    minivan
#    midsize    midsize      Other      Other      Other      Other      Other
#    minivan    minivan    minivan    minivan    minivan    minivan     pickup
#      Other      Other      Other      Other      Other      Other     pickup
#     pickup     pickup     pickup     pickup     pickup     pickup     pickup
#     pickup     pickup     pickup     pickup     pickup     pickup     pickup
#     pickup        suv        suv        suv        suv        suv        suv
#     pickup        suv        suv        suv        suv        suv        suv
#        suv     pickup     pickup     pickup     pickup     pickup     pickup
#        suv     pickup     pickup     pickup     pickup     pickup     pickup
#     pickup     pickup     pickup     pickup        suv        suv        suv
#     pickup     pickup     pickup     pickup        suv        suv        suv
#        suv        suv        suv        suv        suv        suv     pickup
#        suv        suv        suv        suv        suv        suv     pickup
#     pickup     pickup     pickup     pickup     pickup     pickup subcompact
#     pickup     pickup     pickup     pickup     pickup     pickup subcompact
# subcompact subcompact subcompact subcompact subcompact subcompact subcompact
# subcompact subcompact subcompact subcompact subcompact subcompact subcompact
# subcompact subcompact subcompact subcompact subcompact subcompact subcompact
# subcompact subcompact subcompact subcompact subcompact subcompact subcompact
# subcompact subcompact subcompact    midsize    midsize    midsize    midsize
# subcompact subcompact subcompact    midsize    midsize    midsize    midsize
#    midsize    midsize    midsize subcompact subcompact subcompact subcompact
#    midsize    midsize    midsize subcompact subcompact subcompact subcompact
# subcompact subcompact subcompact        suv        suv        suv        suv
# subcompact subcompact subcompact        suv        suv        suv        suv
#        suv        suv        suv        suv        suv        suv        suv
#        suv        suv        suv        suv        suv        suv        suv
#        suv        suv        suv        suv        suv        suv        suv
#        suv        suv        suv        suv        suv        suv        suv
#        suv    compact    compact    midsize    midsize    midsize    midsize
#        suv    compact    compact    midsize    midsize    midsize    midsize
#    midsize    midsize    midsize        suv        suv        suv        suv
#    midsize    midsize    midsize        suv        suv        suv        suv
#    midsize    midsize    midsize    midsize    midsize        suv        suv
#    midsize    midsize    midsize    midsize    midsize        suv        suv
#        suv        suv        suv        suv subcompact subcompact subcompact
#        suv        suv        suv        suv subcompact subcompact subcompact
# subcompact    compact    compact    compact    compact        suv        suv
# subcompact    compact    compact    compact    compact        suv        suv
#        suv        suv        suv        suv    midsize    midsize    midsize
#        suv        suv        suv        suv    midsize    midsize    midsize
#    midsize    midsize    midsize    midsize    compact    compact    compact
#    midsize    midsize    midsize    midsize    compact    compact    compact
#    compact    compact    compact    compact    compact    compact    compact
#    compact    compact    compact    compact    compact    compact    compact
#    compact    compact        suv        suv     pickup     pickup     pickup
#    compact    compact        suv        suv     pickup     pickup     pickup
#     pickup     pickup     pickup     pickup    compact    compact    compact
#     pickup     pickup     pickup     pickup    compact    compact    compact
#    compact    compact    compact    compact    compact    compact    compact
#    compact    compact    compact    compact    compact    compact    compact
#    compact    compact    compact    compact subcompact subcompact subcompact
#    compact    compact    compact    compact subcompact subcompact subcompact
# subcompact subcompact subcompact    midsize    midsize    midsize    midsize
# subcompact subcompact subcompact    midsize    midsize    midsize    midsize
#    midsize    midsize    midsize
#    midsize    midsize    midsize
# Levels: compact midsize pickup subcompact suv Other

# %% [markdown]
# ## Bonus

# %% [markdown]
# Can you group low frequency values and sort the levels by frequency?

# %%
class_col %>% fct_infreq %>% fct_lump(n=5)
# Out:
#    compact    compact    compact    compact    compact    compact    compact
#    compact    compact    compact    compact    compact    compact    compact
#    compact    compact    compact    compact    compact    compact    compact
#    compact    compact    compact    compact    compact    compact    compact
#    compact    midsize    midsize    midsize        suv        suv        suv
#    compact    midsize    midsize    midsize        suv        suv        suv
#        suv        suv    2seater    2seater    2seater    2seater    2seater
#        suv        suv      Other      Other      Other      Other      Other
#        suv        suv        suv        suv    midsize    midsize    midsize
#        suv        suv        suv        suv    midsize    midsize    midsize
#    midsize    midsize    minivan    minivan    minivan    minivan    minivan
#    midsize    midsize      Other      Other      Other      Other      Other
#    minivan    minivan    minivan    minivan    minivan    minivan     pickup
#      Other      Other      Other      Other      Other      Other     pickup
#     pickup     pickup     pickup     pickup     pickup     pickup     pickup
#     pickup     pickup     pickup     pickup     pickup     pickup     pickup
#     pickup        suv        suv        suv        suv        suv        suv
#     pickup        suv        suv        suv        suv        suv        suv
#        suv     pickup     pickup     pickup     pickup     pickup     pickup
#        suv     pickup     pickup     pickup     pickup     pickup     pickup
#     pickup     pickup     pickup     pickup        suv        suv        suv
#     pickup     pickup     pickup     pickup        suv        suv        suv
#        suv        suv        suv        suv        suv        suv     pickup
#        suv        suv        suv        suv        suv        suv     pickup
#     pickup     pickup     pickup     pickup     pickup     pickup subcompact
#     pickup     pickup     pickup     pickup     pickup     pickup subcompact
# subcompact subcompact subcompact subcompact subcompact subcompact subcompact
# subcompact subcompact subcompact subcompact subcompact subcompact subcompact
# subcompact subcompact subcompact subcompact subcompact subcompact subcompact
# subcompact subcompact subcompact subcompact subcompact subcompact subcompact
# subcompact subcompact subcompact    midsize    midsize    midsize    midsize
# subcompact subcompact subcompact    midsize    midsize    midsize    midsize
#    midsize    midsize    midsize subcompact subcompact subcompact subcompact
#    midsize    midsize    midsize subcompact subcompact subcompact subcompact
# subcompact subcompact subcompact        suv        suv        suv        suv
# subcompact subcompact subcompact        suv        suv        suv        suv
#        suv        suv        suv        suv        suv        suv        suv
#        suv        suv        suv        suv        suv        suv        suv
#        suv        suv        suv        suv        suv        suv        suv
#        suv        suv        suv        suv        suv        suv        suv
#        suv    compact    compact    midsize    midsize    midsize    midsize
#        suv    compact    compact    midsize    midsize    midsize    midsize
#    midsize    midsize    midsize        suv        suv        suv        suv
#    midsize    midsize    midsize        suv        suv        suv        suv
#    midsize    midsize    midsize    midsize    midsize        suv        suv
#    midsize    midsize    midsize    midsize    midsize        suv        suv
#        suv        suv        suv        suv subcompact subcompact subcompact
#        suv        suv        suv        suv subcompact subcompact subcompact
# subcompact    compact    compact    compact    compact        suv        suv
# subcompact    compact    compact    compact    compact        suv        suv
#        suv        suv        suv        suv    midsize    midsize    midsize
#        suv        suv        suv        suv    midsize    midsize    midsize
#    midsize    midsize    midsize    midsize    compact    compact    compact
#    midsize    midsize    midsize    midsize    compact    compact    compact
#    compact    compact    compact    compact    compact    compact    compact
#    compact    compact    compact    compact    compact    compact    compact
#    compact    compact        suv        suv     pickup     pickup     pickup
#    compact    compact        suv        suv     pickup     pickup     pickup
#     pickup     pickup     pickup     pickup    compact    compact    compact
#     pickup     pickup     pickup     pickup    compact    compact    compact
#    compact    compact    compact    compact    compact    compact    compact
#    compact    compact    compact    compact    compact    compact    compact
#    compact    compact    compact    compact subcompact subcompact subcompact
#    compact    compact    compact    compact subcompact subcompact subcompact
# subcompact subcompact subcompact    midsize    midsize    midsize    midsize
# subcompact subcompact subcompact    midsize    midsize    midsize    midsize
#    midsize    midsize    midsize
#    midsize    midsize    midsize
# Levels: suv compact midsize subcompact pickup Other
